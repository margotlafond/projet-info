# %% [markdown]
# # Evolution de la popularité des langues de 2019 à 2023

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('lv-college.csv', sep = ';')
df.columns
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_29424\441065526.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('lv-college.csv', sep = ';')
# Index(['num_ligne', 'Rentrée scolaire', 'Code région académique',
#        'Région académique', 'Code académie', 'Académie', 'Code département',
#        'Département', 'Code postal', 'Commune', 'UAI',
#        'Dénomination principale', 'Patronyme', 'Secteur', 'REP', 'REP +',
#        'Nombre d'élèves total', 'Nombre d'élèves total hors Segpa hors ULIS',
#        'Nombre d'élèves total Segpa', 'Nombre d'élèves total ULIS',
#        '6èmes total', '6èmes hors Segpa hors ULIS', '6èmes Segpa',
#        '6èmes ULIS', '6èmes filles', '6èmes garçons', '6èmes LV1 allemand',
#        '6èmes LV1 anglais', '6èmes LV1 espagnol', '6èmes LV1 autres langues',
#        '6èmes LV2 allemand', '6èmes LV2 anglais', '6èmes LV2 espagnol',
# ...

# %% [markdown]
# ## LV1

# %% [markdown]
# ### LV1 anglais

# %%
lv1ang = df.pivot_table(values = ["6èmes LV1 anglais", "5èmes LV1 anglais", "4èmes LV1 anglais", "3èmes LV1 anglais"], index = 'Rentrée scolaire', aggfunc = 'sum')

trois = list(lv1ang['3èmes LV1 anglais'])
quat = list(lv1ang['4èmes LV1 anglais'])
cinq = list(lv1ang['5èmes LV1 anglais'])
six = list(lv1ang['6èmes LV1 anglais'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, six, color='red', label='6èmes')
plt.bar(annees, cinq, color='orange', bottom = six, label='5èmes')
plt.bar(annees, quat, color='yellow', bottom = np.array(cinq)+np.array(six), label='4èmes')
plt.bar(annees, trois, color='green', bottom = np.array(cinq)+np.array(six)+np.array(quat), label='3èmes')

plt.title("Evolution de l'anglais comme LV1 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV1 allemand

# %%
lv1all = df.pivot_table(values = ["6èmes LV1 allemand", "5èmes LV1 allemand", "4èmes LV1 allemand", "3èmes LV1 allemand"], index = 'Rentrée scolaire', aggfunc = 'sum')

all3e1 = list(lv1all['3èmes LV1 allemand'])
all4e1 = list(lv1all['4èmes LV1 allemand'])
all5e1 = list(lv1all['5èmes LV1 allemand'])
all6e1 = list(lv1all['6èmes LV1 allemand'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, all6e1, color='red', label='6èmes')
plt.bar(annees, all5e1, color='orange', bottom = all6e1, label='5èmes')
plt.bar(annees, all4e1, color='yellow', bottom = np.array(all6e1)+np.array(all5e1), label='4èmes')
plt.bar(annees, all3e1, color='green', bottom = np.array(all6e1)+np.array(all5e1)+np.array(all4e1), label='3èmes')

plt.title("Evolution de l'allemand comme LV1 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV1 espagnol

# %% [markdown]
# ## LV2

# %% [markdown]
# ### LV2 anglais

# %%
lv2ang = df.pivot_table(values = ["6èmes LV2 anglais", "5èmes LV2 anglais", "4èmes LV2 anglais", "3èmes LV2 anglais"], index = 'Rentrée scolaire', aggfunc = 'sum')

ang3e2 = list(lv2ang['3èmes LV2 anglais'])
ang4e2 = list(lv2ang['4èmes LV2 anglais'])
ang5e2 = list(lv2ang['5èmes LV2 anglais'])
ang6e2 = list(lv2ang['6èmes LV2 anglais'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, ang6e2, color='red', label='6èmes')
plt.bar(annees, ang5e2, color='orange', bottom = ang6e2, label='5èmes')
plt.bar(annees, ang4e2, color='yellow', bottom = np.array(ang6e2)+np.array(ang5e2), label='4èmes')
plt.bar(annees, ang3e2, color='green', bottom = np.array(ang6e2)+np.array(ang5e2)+np.array(ang4e2), label='3èmes')

plt.title("Evolution de l'anglais comme LV2 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()
