# %% [markdown]
# # Evolution de la popularité des langues de 2019 à 2023

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('lv-college.csv', sep = ';')
df.columns
# Out:
# C:\Users\marie\AppData\Local\Temp\ipykernel_12328\441065526.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('lv-college.csv', sep = ';')
# Index(['num_ligne', 'Rentrée scolaire', 'Code région académique',
#        'Région académique', 'Code académie', 'Académie', 'Code département',
#        'Département', 'Code postal', 'Commune', 'UAI',
#        'Dénomination principale', 'Patronyme', 'Secteur', 'REP', 'REP +',
#        'Nombre d'élèves total', 'Nombre d'élèves total hors Segpa hors ULIS',
#        'Nombre d'élèves total Segpa', 'Nombre d'élèves total ULIS',
#        '6èmes total', '6èmes hors Segpa hors ULIS', '6èmes Segpa',
#        '6èmes ULIS', '6èmes filles', '6èmes garçons', '6èmes LV1 allemand',
#        '6èmes LV1 anglais', '6èmes LV1 espagnol', '6èmes LV1 autres langues',
#        '6èmes LV2 allemand', '6èmes LV2 anglais', '6èmes LV2 espagnol',
# ...

# %% [markdown]
# ## LV1

# %% [markdown]
# ### LV1 anglais

# %%
lv1ang = df.pivot_table(values = ["6èmes LV1 anglais", "5èmes LV1 anglais", "4èmes LV1 anglais", "3èmes LV1 anglais"], index = 'Rentrée scolaire', aggfunc = 'sum')

trois = list(lv1ang['3èmes LV1 anglais'])
quat = list(lv1ang['4èmes LV1 anglais'])
cinq = list(lv1ang['5èmes LV1 anglais'])
six = list(lv1ang['6èmes LV1 anglais'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, six, color='red', label='6èmes')
plt.bar(annees, cinq, color='orange', bottom = six, label='5èmes')
plt.bar(annees, quat, color='yellow', bottom = np.array(cinq)+np.array(six), label='4èmes')
plt.bar(annees, trois, color='green', bottom = np.array(cinq)+np.array(six)+np.array(quat), label='3èmes')

plt.title("Evolution de l'anglais comme LV1 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV1 allemand

# %%
lv1all = df.pivot_table(values = ["6èmes LV1 allemand", "5èmes LV1 allemand", "4èmes LV1 allemand", "3èmes LV1 allemand"], index = 'Rentrée scolaire', aggfunc = 'sum')

all3e1 = list(lv1all['3èmes LV1 allemand'])
all4e1 = list(lv1all['4èmes LV1 allemand'])
all5e1 = list(lv1all['5èmes LV1 allemand'])
all6e1 = list(lv1all['6èmes LV1 allemand'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, all6e1, color='red', label='6èmes')
plt.bar(annees, all5e1, color='orange', bottom = all6e1, label='5èmes')
plt.bar(annees, all4e1, color='yellow', bottom = np.array(all6e1)+np.array(all5e1), label='4èmes')
plt.bar(annees, all3e1, color='green', bottom = np.array(all6e1)+np.array(all5e1)+np.array(all4e1), label='3èmes')

plt.title("Evolution de l'allemand comme LV1 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV1 espagnol

# %%
lv1esp = df.pivot_table(values = ["6èmes LV1 espagnol", "5èmes LV1 espagnol", "4èmes LV1 espagnol", "3èmes LV1 espagnol"], index = 'Rentrée scolaire', aggfunc = 'sum')

esp3e1 = list(lv1esp['3èmes LV1 espagnol'])
esp4e1 = list(lv1esp['4èmes LV1 espagnol'])
esp5e1 = list(lv1esp['5èmes LV1 espagnol'])
esp6e1 = list(lv1esp['6èmes LV1 espagnol'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, esp6e1, color='red', label='6èmes')
plt.bar(annees, esp5e1, color='orange', bottom = esp6e1, label='5èmes')
plt.bar(annees, esp4e1, color='yellow', bottom = np.array(esp6e1)+np.array(esp5e1), label='4èmes')
plt.bar(annees, esp3e1, color='green', bottom = np.array(esp6e1)+np.array(esp5e1)+np.array(esp4e1), label='3èmes')

plt.title("Evolution de l'espagnol comme LV1 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV1 autres langues

# %%
lv1autre = df.pivot_table(values = ["6èmes LV1 autres langues", "5èmes LV1 autres langues", "4èmes LV1 autres langues", "3èmes LV1 autres langues"], index = 'Rentrée scolaire', aggfunc = 'sum')

autre3e1 = list(lv1autre['3èmes LV1 autres langues'])
autre4e1 = list(lv1autre['4èmes LV1 autres langues'])
autre5e1 = list(lv1autre['5èmes LV1 autres langues'])
autre6e1 = list(lv1autre['6èmes LV1 autres langues'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, autre6e1, color='red', label='6èmes')
plt.bar(annees, autre5e1, color='orange', bottom = autre6e1, label='5èmes')
plt.bar(annees, autre4e1, color='yellow', bottom = np.array(autre6e1)+np.array(autre5e1), label='4èmes')
plt.bar(annees, autre3e1, color='green', bottom = np.array(autre6e1)+np.array(autre5e1)+np.array(autre4e1), label='3èmes')

plt.title("Evolution des 'autres langues' comme LV1 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ## LV2

# %% [markdown]
# ### LV2 anglais

# %%
lv2ang = df.pivot_table(values = ["6èmes LV2 anglais", "5èmes LV2 anglais", "4èmes LV2 anglais", "3èmes LV2 anglais"], index = 'Rentrée scolaire', aggfunc = 'sum')

ang3e2 = list(lv2ang['3èmes LV2 anglais'])
ang4e2 = list(lv2ang['4èmes LV2 anglais'])
ang5e2 = list(lv2ang['5èmes LV2 anglais'])
ang6e2 = list(lv2ang['6èmes LV2 anglais'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, ang6e2, color='red', label='6èmes')
plt.bar(annees, ang5e2, color='orange', bottom = ang6e2, label='5èmes')
plt.bar(annees, ang4e2, color='yellow', bottom = np.array(ang6e2)+np.array(ang5e2), label='4èmes')
plt.bar(annees, ang3e2, color='green', bottom = np.array(ang6e2)+np.array(ang5e2)+np.array(ang4e2), label='3èmes')

plt.title("Evolution de l'anglais comme LV2 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV2 allemand

# %%
lv2all = df.pivot_table(values = ["6èmes LV2 allemand", "5èmes LV2 allemand", "4èmes LV2 allemand", "3èmes LV2 allemand"], index = 'Rentrée scolaire', aggfunc = 'sum')

all3e2 = list(lv2all['3èmes LV2 allemand'])
all4e2 = list(lv2all['4èmes LV2 allemand'])
all5e2 = list(lv2all['5èmes LV2 allemand'])
all6e2 = list(lv2all['6èmes LV2 allemand'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, all6e2, color='red', label='6èmes')
plt.bar(annees, all5e2, color='orange', bottom = all6e2, label='5èmes')
plt.bar(annees, all4e2, color='yellow', bottom = np.array(all6e2)+np.array(all5e2), label='4èmes')
plt.bar(annees, all3e2, color='green', bottom = np.array(all6e2)+np.array(all5e2)+np.array(all4e2), label='3èmes')

plt.title("Evolution de l'allemand comme LV2 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV2 espagnol

# %%
lv2esp = df.pivot_table(values = ["6èmes LV2 espagnol", "5èmes LV2 espagnol", "4èmes LV2 espagnol", "3èmes LV2 espagnol"], index = 'Rentrée scolaire', aggfunc = 'sum')

esp3e2 = list(lv2esp['3èmes LV2 espagnol'])
esp4e2 = list(lv2esp['4èmes LV2 espagnol'])
esp5e2 = list(lv2esp['5èmes LV2 espagnol'])
esp6e2 = list(lv2esp['6èmes LV2 espagnol'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, esp6e2, color='red', label='6èmes')
plt.bar(annees, esp5e2, color='orange', bottom = esp6e2, label='5èmes')
plt.bar(annees, esp4e2, color='yellow', bottom = np.array(esp6e2)+np.array(esp5e2), label='4èmes')
plt.bar(annees, esp3e2, color='green', bottom = np.array(esp6e2)+np.array(esp5e2)+np.array(esp4e2), label='3èmes')

plt.title("Evolution de l'espagnol comme LV2 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %%
# Analyse : très peu de 6èmes car on commence souvent l'espagnol en 5ème

# %% [markdown]
# ### LV2 italien

# %%
lv2ita = df.pivot_table(values = ["6èmes LV2 italien", "5èmes LV2 italien", "4èmes LV2 italien", "3èmes LV2 italien"], index = 'Rentrée scolaire', aggfunc = 'sum')

ita3e2 = list(lv2ita['3èmes LV2 italien'])
ita4e2 = list(lv2ita['4èmes LV2 italien'])
ita5e2 = list(lv2ita['5èmes LV2 italien'])
ita6e2 = list(lv2ita['6èmes LV2 italien'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, ita6e2, color='red', label='6èmes')
plt.bar(annees, ita5e2, color='orange', bottom = ita6e2, label='5èmes')
plt.bar(annees, ita4e2, color='yellow', bottom = np.array(ita6e2)+np.array(ita5e2), label='4èmes')
plt.bar(annees, ita3e2, color='green', bottom = np.array(ita6e2)+np.array(ita5e2)+np.array(ita4e2), label='3èmes')

plt.title("Evolution de l'italien comme LV2 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### LV2 autres langues

# %%
lv2autre = df.pivot_table(values = ["6ème LV2 autres langues", "5èmes LV2 autres langues", "4èmes LV2 autres langues", "3èmes LV2 autres langues"], index = 'Rentrée scolaire', aggfunc = 'sum')

autre3e2 = list(lv2autre['3èmes LV2 autres langues'])
autre4e2 = list(lv2autre['4èmes LV2 autres langues'])
autre5e2 = list(lv2autre['5èmes LV2 autres langues'])
autre6e2 = list(lv2autre['6ème LV2 autres langues'])
annees = [2019, 2020, 2021, 2022, 2023]

plt.bar(annees, autre6e2, color='red', label='6èmes')
plt.bar(annees, autre5e2, color='orange', bottom = autre6e2, label='5èmes')
plt.bar(annees, autre4e2, color='yellow', bottom = np.array(autre6e2)+np.array(autre5e2), label='4èmes')
plt.bar(annees, autre3e2, color='green', bottom = np.array(autre6e2)+np.array(autre5e2)+np.array(autre4e2), label='3èmes')

plt.title("Evolution des 'autres langues' comme LV2 de 2019 à 2023")
plt.xlabel('Années')
plt.ylabel("Nombre d'élèves")
plt.legend(loc = 'lower right')
plt.show()
